# %%
import pandas as pd

def create_tidy_dataframe(text, infinitive=None):
    subjects = [
        "Aš",
        "Tu",
        "Jis/ji",
        "Mes",
        "Jūs",
        "Jie/jos",
    ]
    tenses = [
        "Present tense",
        "Past tense",
        "Future tense",
        "Conditional mood",
        "Imperative mood",
        "Past freq. tense",
    ]
    
    # Check if all subjects and tenses are present in the text
    for subject in subjects:
        if subject not in text:
            print(f'subject not found: {subject}')
            raise ValueError
    for tense in tenses:
        if tense not in text:
            print(f'tense not found: {tense}')
            raise ValueError

    if infinitive is None:
        print("what verb is being conjugated?")
        raise ValueError

    # Split the text into lines
    lines = text.strip().split('\n')

    # Initialize lists to store the tidy data
    subject_list = []
    tense_list = []
    conjugation_list = []

    # Initialize the current tense and subject index
    current_tense = ""
    subject_index = 0

    # Iterate over each line
    for line in lines:
        if line in tenses:
            current_tense = line.lower().replace(".", "").replace(" ", "_")
            subject_index = 0
        elif line in subjects:
            # Skip the lines containing only subjects
            continue
        else:
            if current_tense == "imperative_mood":
                if subject_index == 0:
                    subject_list.append("tu")
                    tense_list.append(current_tense)
                    conjugation_list.append(line)
                elif subject_index == 1:
                    subject_list.append("jūs")
                    tense_list.append(current_tense)
                    conjugation_list.append(line)
                subject_index += 1
            else:
                if subject_index < len(subjects):
                    subject = subjects[subject_index].lower()
                    if "/" in subject:
                        for sub in subject.split("/"):
                            subject_list.append(sub)
                            tense_list.append(current_tense)
                            conjugation_list.append(line)
                    else:
                        subject_list.append(subject)
                        tense_list.append(current_tense)
                        conjugation_list.append(line)
                subject_index += 1

    # Create a tidy DataFrame
    df = pd.DataFrame({
        'subject': subject_list,
        'tense': tense_list,
        'conjugation': conjugation_list
    })
    df['infinitive'] = infinitive
    return df

# %%
buti = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
esu
esi
yra
esame
esate
yra
Past tense
buvau
buvai
buvo
buvome
buvote
buvo
Future tense
būsiu
būsi
bus
būsime
būsite
bus
Conditional mood
būčiau
būtum
būtų
būtumėme
būtumėte
būtų
Tu
Jūs
Imperative mood
būk
būkite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
būdavau
būdavai
būdavo
būdavome
būdavote
būdavo
"""

# %%
bdf = create_tidy_dataframe(buti,  "būti")

# %%
bdf
# Out:
#    subject             tense conjugation infinitive
# 0       aš     present_tense         esu       būti
# 1       tu     present_tense         esi       būti
# 2      jis     present_tense         yra       būti
# 3       ji     present_tense         yra       būti
# 4      mes     present_tense       esame       būti
# 5      jūs     present_tense       esate       būti
# 6      jie     present_tense         yra       būti
# 7      jos     present_tense         yra       būti
# 8       aš        past_tense       buvau       būti
# 9       tu        past_tense       buvai       būti
# 10     jis        past_tense        buvo       būti
# 11      ji        past_tense        buvo       būti
# 12     mes        past_tense      buvome       būti
# 13     jūs        past_tense      buvote       būti
# 14     jie        past_tense        buvo       būti
# 15     jos        past_tense        buvo       būti
# 16      aš      future_tense       būsiu       būti
# 17      tu      future_tense        būsi       būti
# 18     jis      future_tense         bus       būti
# 19      ji      future_tense         bus       būti
# 20     mes      future_tense      būsime       būti
# 21     jūs      future_tense      būsite       būti
# 22     jie      future_tense         bus       būti
# 23     jos      future_tense         bus       būti
# 24      aš  conditional_mood      būčiau       būti
# 25      tu  conditional_mood       būtum       būti
# 26     jis  conditional_mood        būtų       būti
# 27      ji  conditional_mood        būtų       būti
# 28     mes  conditional_mood    būtumėme       būti
# 29     jūs  conditional_mood    būtumėte       būti
# 30     jie  conditional_mood        būtų       būti
# 31     jos  conditional_mood        būtų       būti
# 32      tu   imperative_mood         būk       būti
# 33     jūs   imperative_mood      būkite       būti
# 34      aš   past_freq_tense     būdavau       būti
# 35      tu   past_freq_tense     būdavai       būti
# 36     jis   past_freq_tense      būdavo       būti
# 37      ji   past_freq_tense      būdavo       būti
# 38     mes   past_freq_tense    būdavome       būti
# 39     jūs   past_freq_tense    būdavote       būti
# 40     jie   past_freq_tense      būdavo       būti
# 41     jos   past_freq_tense      būdavo       būti

# %%
matyti = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
matau
matai
mato
matome
matote
mato
Past tense
mačiau
matei
matė
matėme
matėte
matė
Future tense
matysiu
matysi
matys
matysime
matysite
matys
Conditional mood
matyčiau
matytum
matytų
matytume
matytute
matytų
Tu
Jūs
Imperative mood
matyk
matykite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
matydavau
matydavai
matydavo
matydavome
matydavote
matydavo
"""

# %%
mdf = create_tidy_dataframe(matyti, "matyti")

# %%
mdf
# Out:
#    subject             tense conjugation infinitive
# 0       aš     present_tense       matau     matyti
# 1       tu     present_tense       matai     matyti
# 2      jis     present_tense        mato     matyti
# 3       ji     present_tense        mato     matyti
# 4      mes     present_tense      matome     matyti
# 5      jūs     present_tense      matote     matyti
# 6      jie     present_tense        mato     matyti
# 7      jos     present_tense        mato     matyti
# 8       aš        past_tense      mačiau     matyti
# 9       tu        past_tense       matei     matyti
# 10     jis        past_tense        matė     matyti
# 11      ji        past_tense        matė     matyti
# 12     mes        past_tense      matėme     matyti
# 13     jūs        past_tense      matėte     matyti
# 14     jie        past_tense        matė     matyti
# 15     jos        past_tense        matė     matyti
# 16      aš      future_tense     matysiu     matyti
# 17      tu      future_tense      matysi     matyti
# 18     jis      future_tense       matys     matyti
# 19      ji      future_tense       matys     matyti
# 20     mes      future_tense    matysime     matyti
# 21     jūs      future_tense    matysite     matyti
# 22     jie      future_tense       matys     matyti
# 23     jos      future_tense       matys     matyti
# 24      aš  conditional_mood    matyčiau     matyti
# 25      tu  conditional_mood     matytum     matyti
# 26     jis  conditional_mood      matytų     matyti
# 27      ji  conditional_mood      matytų     matyti
# 28     mes  conditional_mood    matytume     matyti
# 29     jūs  conditional_mood    matytute     matyti
# 30     jie  conditional_mood      matytų     matyti
# 31     jos  conditional_mood      matytų     matyti
# 32      tu   imperative_mood       matyk     matyti
# 33     jūs   imperative_mood    matykite     matyti
# 34      aš   past_freq_tense   matydavau     matyti
# 35      tu   past_freq_tense   matydavai     matyti
# 36     jis   past_freq_tense    matydavo     matyti
# 37      ji   past_freq_tense    matydavo     matyti
# 38     mes   past_freq_tense  matydavome     matyti
# 39     jūs   past_freq_tense  matydavote     matyti
# 40     jie   past_freq_tense    matydavo     matyti
# 41     jos   past_freq_tense    matydavo     matyti

# %%
meg = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
mėgstu
mėgsti
mėgsta
mėgstame
mėgstate
mėgsta
Past tense
mėgau
mėgai
mėgo
mėgome
mėgote
mėgo
Future tense
mėgsiu
mėgsi
mėgs
mėgsime
mėgsite
mėgs
Conditional mood
mėgčiau
mėgtum
mėgtų
mėgtume
mėgtute
mėgtų
Tu
Jūs
Imperative mood
mėk
mėkite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
mėgdavau
mėgdavai
mėgdavo
mėgdavome
mėgdavote
mėgdavo
"""
megdf = create_tidy_dataframe(meg, "mėgti")

# %%
megdf
# Out:
#    subject             tense conjugation infinitive
# 0       aš     present_tense      mėgstu      mėgti
# 1       tu     present_tense      mėgsti      mėgti
# 2      jis     present_tense      mėgsta      mėgti
# 3       ji     present_tense      mėgsta      mėgti
# 4      mes     present_tense    mėgstame      mėgti
# 5      jūs     present_tense    mėgstate      mėgti
# 6      jie     present_tense      mėgsta      mėgti
# 7      jos     present_tense      mėgsta      mėgti
# 8       aš        past_tense       mėgau      mėgti
# 9       tu        past_tense       mėgai      mėgti
# 10     jis        past_tense        mėgo      mėgti
# 11      ji        past_tense        mėgo      mėgti
# 12     mes        past_tense      mėgome      mėgti
# 13     jūs        past_tense      mėgote      mėgti
# 14     jie        past_tense        mėgo      mėgti
# 15     jos        past_tense        mėgo      mėgti
# 16      aš      future_tense      mėgsiu      mėgti
# 17      tu      future_tense       mėgsi      mėgti
# 18     jis      future_tense        mėgs      mėgti
# 19      ji      future_tense        mėgs      mėgti
# 20     mes      future_tense     mėgsime      mėgti
# 21     jūs      future_tense     mėgsite      mėgti
# 22     jie      future_tense        mėgs      mėgti
# 23     jos      future_tense        mėgs      mėgti
# 24      aš  conditional_mood     mėgčiau      mėgti
# 25      tu  conditional_mood      mėgtum      mėgti
# 26     jis  conditional_mood       mėgtų      mėgti
# 27      ji  conditional_mood       mėgtų      mėgti
# 28     mes  conditional_mood     mėgtume      mėgti
# 29     jūs  conditional_mood     mėgtute      mėgti
# 30     jie  conditional_mood       mėgtų      mėgti
# 31     jos  conditional_mood       mėgtų      mėgti
# 32      tu   imperative_mood         mėk      mėgti
# 33     jūs   imperative_mood      mėkite      mėgti
# 34      aš   past_freq_tense    mėgdavau      mėgti
# 35      tu   past_freq_tense    mėgdavai      mėgti
# 36     jis   past_freq_tense     mėgdavo      mėgti
# 37      ji   past_freq_tense     mėgdavo      mėgti
# 38     mes   past_freq_tense   mėgdavome      mėgti
# 39     jūs   past_freq_tense   mėgdavote      mėgti
# 40     jie   past_freq_tense     mėgdavo      mėgti
# 41     jos   past_freq_tense     mėgdavo      mėgti

# %%
nor = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
noriu
nori
nori
norime
norite
nori
Past tense
norėjau
norėjai
norėjo
norėjome
norėjote
norėjo
Future tense
norėsiu
norėsi
norės
norėsime
norėsite
norės
Conditional mood
norėčiau
norėtum
norėtų
norėtume
norėtute
norėtų
Tu
Jūs
Imperative mood
norėk
norėkite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
norėdavau
norėdavai
norėdavo
norėdavome
norėdavote
norėdavo
"""
nordf = create_tidy_dataframe(nor, 'norėti')

# %%
nordf
# Out:
#    subject             tense conjugation infinitive
# 0       aš     present_tense       noriu     norėti
# 1       tu     present_tense        nori     norėti
# 2      jis     present_tense        nori     norėti
# 3       ji     present_tense        nori     norėti
# 4      mes     present_tense      norime     norėti
# 5      jūs     present_tense      norite     norėti
# 6      jie     present_tense        nori     norėti
# 7      jos     present_tense        nori     norėti
# 8       aš        past_tense     norėjau     norėti
# 9       tu        past_tense     norėjai     norėti
# 10     jis        past_tense      norėjo     norėti
# 11      ji        past_tense      norėjo     norėti
# 12     mes        past_tense    norėjome     norėti
# 13     jūs        past_tense    norėjote     norėti
# 14     jie        past_tense      norėjo     norėti
# 15     jos        past_tense      norėjo     norėti
# 16      aš      future_tense     norėsiu     norėti
# 17      tu      future_tense      norėsi     norėti
# 18     jis      future_tense       norės     norėti
# 19      ji      future_tense       norės     norėti
# 20     mes      future_tense    norėsime     norėti
# 21     jūs      future_tense    norėsite     norėti
# 22     jie      future_tense       norės     norėti
# 23     jos      future_tense       norės     norėti
# 24      aš  conditional_mood    norėčiau     norėti
# 25      tu  conditional_mood     norėtum     norėti
# 26     jis  conditional_mood      norėtų     norėti
# 27      ji  conditional_mood      norėtų     norėti
# 28     mes  conditional_mood    norėtume     norėti
# 29     jūs  conditional_mood    norėtute     norėti
# 30     jie  conditional_mood      norėtų     norėti
# 31     jos  conditional_mood      norėtų     norėti
# 32      tu   imperative_mood       norėk     norėti
# 33     jūs   imperative_mood    norėkite     norėti
# 34      aš   past_freq_tense   norėdavau     norėti
# 35      tu   past_freq_tense   norėdavai     norėti
# 36     jis   past_freq_tense    norėdavo     norėti
# 37      ji   past_freq_tense    norėdavo     norėti
# 38     mes   past_freq_tense  norėdavome     norėti
# 39     jūs   past_freq_tense  norėdavote     norėti
# 40     jie   past_freq_tense    norėdavo     norėti
# 41     jos   past_freq_tense    norėdavo     norėti

# %%
pra = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
prašau
prašai
prašo
prašome
prašote
prašo
Past tense
prašiau
prašei
prašė
prašėme
prašėte
prašė
Future tense
prašysiu
prašysi
prašys
prašysime
prašysite
prašys
Conditional mood
prašyčiau
prašytum
prašytų
prašytume
prašytute
prašytų
Tu
Jūs
Imperative mood
prašyk
prašykite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
prašydavau
prašydavai
prašydavo
prašydavome
prašydavote
prašydavo
"""

pradf = create_tidy_dataframe(pra, "prašyti")

# %%
pradf
# Out:
#    subject             tense  conjugation infinitive
# 0       aš     present_tense       prašau    prašyti
# 1       tu     present_tense       prašai    prašyti
# 2      jis     present_tense        prašo    prašyti
# 3       ji     present_tense        prašo    prašyti
# 4      mes     present_tense      prašome    prašyti
# 5      jūs     present_tense      prašote    prašyti
# 6      jie     present_tense        prašo    prašyti
# 7      jos     present_tense        prašo    prašyti
# 8       aš        past_tense      prašiau    prašyti
# 9       tu        past_tense       prašei    prašyti
# 10     jis        past_tense        prašė    prašyti
# 11      ji        past_tense        prašė    prašyti
# 12     mes        past_tense      prašėme    prašyti
# 13     jūs        past_tense      prašėte    prašyti
# 14     jie        past_tense        prašė    prašyti
# 15     jos        past_tense        prašė    prašyti
# 16      aš      future_tense     prašysiu    prašyti
# 17      tu      future_tense      prašysi    prašyti
# 18     jis      future_tense       prašys    prašyti
# 19      ji      future_tense       prašys    prašyti
# 20     mes      future_tense    prašysime    prašyti
# 21     jūs      future_tense    prašysite    prašyti
# 22     jie      future_tense       prašys    prašyti
# 23     jos      future_tense       prašys    prašyti
# 24      aš  conditional_mood    prašyčiau    prašyti
# 25      tu  conditional_mood     prašytum    prašyti
# 26     jis  conditional_mood      prašytų    prašyti
# 27      ji  conditional_mood      prašytų    prašyti
# 28     mes  conditional_mood    prašytume    prašyti
# 29     jūs  conditional_mood    prašytute    prašyti
# 30     jie  conditional_mood      prašytų    prašyti
# 31     jos  conditional_mood      prašytų    prašyti
# 32      tu   imperative_mood       prašyk    prašyti
# 33     jūs   imperative_mood    prašykite    prašyti
# 34      aš   past_freq_tense   prašydavau    prašyti
# 35      tu   past_freq_tense   prašydavai    prašyti
# 36     jis   past_freq_tense    prašydavo    prašyti
# 37      ji   past_freq_tense    prašydavo    prašyti
# 38     mes   past_freq_tense  prašydavome    prašyti
# 39     jūs   past_freq_tense  prašydavote    prašyti
# 40     jie   past_freq_tense    prašydavo    prašyti
# 41     jos   past_freq_tense    prašydavo    prašyti

# %%
valgyti = """Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Present tense
valgau
valgai
valgo
valgome
valgote
valgo
Past tense
valgiau
valgei
valgė
valgėme
valgėte
valgė
Future tense
valgysiu
valgysi
valgys
valgysime
valgysite
valgys
Conditional mood
valgyčiau
valgytum
valgytų
valgytume
valgytute
valgytų
Tu
Jūs
Imperative mood
valgyk
valgykite
Aš
Tu
Jis/ji
Mes
Jūs
Jie/jos
Past freq. tense
valgydavau
valgydavai
valgydavo
valgydavome
valgydavote
valgydavo
"""
valdf = create_tidy_dataframe(valgyti, "valgyti")

# %%
valdf
# Out:
#    subject             tense  conjugation infinitive
# 0       aš     present_tense       valgau    valgyti
# 1       tu     present_tense       valgai    valgyti
# 2      jis     present_tense        valgo    valgyti
# 3       ji     present_tense        valgo    valgyti
# 4      mes     present_tense      valgome    valgyti
# 5      jūs     present_tense      valgote    valgyti
# 6      jie     present_tense        valgo    valgyti
# 7      jos     present_tense        valgo    valgyti
# 8       aš        past_tense      valgiau    valgyti
# 9       tu        past_tense       valgei    valgyti
# 10     jis        past_tense        valgė    valgyti
# 11      ji        past_tense        valgė    valgyti
# 12     mes        past_tense      valgėme    valgyti
# 13     jūs        past_tense      valgėte    valgyti
# 14     jie        past_tense        valgė    valgyti
# 15     jos        past_tense        valgė    valgyti
# 16      aš      future_tense     valgysiu    valgyti
# 17      tu      future_tense      valgysi    valgyti
# 18     jis      future_tense       valgys    valgyti
# 19      ji      future_tense       valgys    valgyti
# 20     mes      future_tense    valgysime    valgyti
# 21     jūs      future_tense    valgysite    valgyti
# 22     jie      future_tense       valgys    valgyti
# 23     jos      future_tense       valgys    valgyti
# 24      aš  conditional_mood    valgyčiau    valgyti
# 25      tu  conditional_mood     valgytum    valgyti
# 26     jis  conditional_mood      valgytų    valgyti
# 27      ji  conditional_mood      valgytų    valgyti
# 28     mes  conditional_mood    valgytume    valgyti
# 29     jūs  conditional_mood    valgytute    valgyti
# 30     jie  conditional_mood      valgytų    valgyti
# 31     jos  conditional_mood      valgytų    valgyti
# 32      tu   imperative_mood       valgyk    valgyti
# 33     jūs   imperative_mood    valgykite    valgyti
# 34      aš   past_freq_tense   valgydavau    valgyti
# 35      tu   past_freq_tense   valgydavai    valgyti
# 36     jis   past_freq_tense    valgydavo    valgyti
# 37      ji   past_freq_tense    valgydavo    valgyti
# 38     mes   past_freq_tense  valgydavome    valgyti
# 39     jūs   past_freq_tense  valgydavote    valgyti
# 40     jie   past_freq_tense    valgydavo    valgyti
# 41     jos   past_freq_tense    valgydavo    valgyti
